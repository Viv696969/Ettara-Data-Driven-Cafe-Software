# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
zomato_link="https://www.zomato.com/mumbai/ettarra-1-juhu/reviews"

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}

r = requests.get(zomato_link, headers=headers)

# %%
print(r.status_code)
# Out:
# 200

# %%
soup=BeautifulSoup(r.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://googleads.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://jumbo.zomato.com" rel="preconnect"/>
#   <link href="https://accounts.google.com" rel="preconnect"/>
#   <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://www.googleadservices.com" rel="preconnect"/>
#   <link href="https://bat.bing.com" rel="preconnect"/>
#   <link href="https://8391443.fls.doubleclick.net" rel="preconnect"/>
#   <title data-rh="true">
#    Reviews of Ettarra, Juhu, Mumbai | Zomato
#   </title>
#   <meta charset="utf-8" data-rh="true">
#    <meta content="NOODP,NOYDIR" data-rh="true" name="robots"/>
#    <meta content="Reviews of Ettarra Juhu; see all unbiased reviews of Ettarra Mumbai for delivery and dining on Zomato." data-rh="true" name="description"/>
#    <meta content="summary" data-rh="true" name="twitter:card"/>
#    <meta content="Reviews of Ettarra, Juhu, Mumbai | Zomato " data-rh="true" property="og:title"/>
#    <meta content="/mumbai/ettarra-1-juhu/reviews" data-rh="true" property="og:image"/>
#    <meta content="Reviews of Ettarra Juhu; see all unbiased reviews of Ettarra Mumbai for delivery and dining on Zomato." data-rh="true" property="og:description"/>
#    <meta content="wpKLzkoQQlIQcu2LzlVmxVTVJbvUyazijG6QYaTzXqw" data-rh="true" name="google-site-verification"/>
#    <link data-rh="true" href="https://www.zomato.com/mumbai/ettarra-1-juhu/reviews" hreflang="en-in" rel="alternate">
#     <link data-rh="true" href="https://www.zomato.com/hi/mumbai/ettarra-1-juhu/reviews" hreflang="hi-in" rel="alternate">
#      <link data-rh="true" href="https://www.zomato.com/bn/mumbai/ettarra-1-juhu/reviews" hreflang="bn-in" rel="alternate">
#       <link data-rh="true" href="https://www.zomato.com/te/mumbai/ettarra-1-juhu/reviews" hreflang="te-in" rel="alternate">
#        <link data-rh="true" href="https://www.zomato.com/ta/mumbai/ettarra-1-juhu/reviews" hreflang="ta-in" rel="alternate">
#         <link data-rh="true" href="https://www.zomato.com/kn/mumbai/ettarra-1-juhu/reviews" hreflang="kn-in" rel="alternate">
#          <link data-rh="true" href="https://www.zomato.com/mr/mumbai/ettarra-1-juhu/reviews" hreflang="mr-in" rel="alternate">
#           <link data-rh="true" href="https://www.zomato.com/gu/mumbai/ettarra-1-juhu/reviews" hreflang="gu-in" rel="alternate">
#            <link data-rh="true" href="https://www.zomato.com/pa/mumbai/ettarra-1-juhu/reviews" hreflang="pa-in" rel="alternate"/>
#            <link data-rh="true" href="https://www.zomato.com/ml/mumbai/ettarra-1-juhu/reviews" hreflang="ml-in" rel="alternate"/>
#            <link data-rh="true" href="https://www.zomato.com/or/mumbai/ettarra-1-juhu/reviews" hreflang="or-in" rel="alternate"/>
#            <link data-rh="true" href="https://www.zomato.com/hi-en/mumbai/ettarra-1-juhu/reviews" hreflang="hi-en-in" rel="alternate"/>
#            <link data-rh="true" href="https://www.zomato.com/mumbai/ettarra-1-juhu/reviews" hreflang="x-default" rel="alternate"/>
#            <link data-rh="true" href="https://www.zomato.com/mumbai/ettarra-1-juhu/reviews" rel="canonical"/>
#            <link data-rh="true" href="https://www.zomato.com/mumbai/ettarra-1-juhu/reviews?amp=1" rel="amphtml"/>
#            <script data-rh="true" type="application/ld+json">
#             {"@context":"http://schema.org","@type":"WebSite","name":"Zomato","url":"https://www.zomato.com"}
#            </script>
#            <script data-rh="true" type="application/ld+json">
#             {"@context":"https://schema.org","@type":"Restaurant","name":"Ettarra","url":"/mumbai/ettarra-1-juhu","openingHours":"Opens tomorrow at 12midnight","hasmap":"https://maps.zomato.com/php/staticmap?center=19.1013203764,72.8273525931&maptype=zomato&markers=19.1013203764,72.8273525931,pin_res32&sensor=false&scale=2&zoom=16&language=en&size=240x150&size=400x240","menu":"/mumbai/ettarra-1-juhu/menu","address":{"@type":"PostalAddress","streetAddress":"#148 B, Ground Floor, Juhu Residency, Juhu Tara Road, Juhu, Mumbai","addressLocality":"Juhu Residency Boutique Hotel, Juhu, Mumbai","addressRegion":"Mumbai","postalCode":"","addressCountry":"India"},"geo":{"@type":"GeoCoordinates","latitude":"19.1013203764","longitude":"72.8273525931"},"potentialAction":{"@type":"OrderAction","deliveryMethod":["http://purl.org/goodrelations/v1#DeliveryModeOwnFleet"],"target":{"@type":"EntryPoint","inLanguage":"en-US","url":"/mumbai/ettarra-1-juhu/book","actionPlatform":["http://schema.org/DesktopWebPlatform","http://schema.org/MobileWebPlatform","http://schema.org/IOSPlatform","http://schema.org/AndroidPlatform"]},"inLanguage":""},"telephone":"+918655805815","priceRange":"","paymentAccepted":"","image":"https://b.zmtcdn.com/data/pictures/chains/5/20468935/eb6d453b422c24f2c9b08862878c73a5.jpg","servesCuisine":"Cafe, Desserts, Coffee, Bakery, Beverages, Shake","aggregateRating":{"@type":"AggregateRating","ratingValue":"4.8","ratingCount":201,"bestRating":5,"worstRating":0},"reviews":[{"author":"Khushboo Ratnani","url":"https://www.zoma.to/OYKBrZP","description":"Many stories with the place,,,,, it has this unexplained vibe which attracts me everytime and to be specific, I have got all my special friends to visit her","reviewRating":{"@type":"Rating","ratingValue":5,"bestRating":5,"worstRating":0}},{"author":"Renu Joshi","url":"https://www.zoma.to/ZLnRzmz","description":"You forgot to send sugar with coffee/the rest of your coffee is good","reviewRating":{"@type":"Rating","ratingValue":3,"bestRating":5,"worstRating":0}},{"author":"Vedant","url":"https://www.zoma.to/ebmMRXx","description":"The filter coffee was brilliant and so were snacks. We had the drizzled paparoti and Nutella Berliner which were lip smacking good. They serve complimentary banana chips which were one of the best I have had in a while. Asif Sheikh- our server was very courteous.","reviewRating":{"@type":"Rating","ratingValue":5,"bestRating":5,"worstRating":0}},{"author":"Archis","url":"https://www.zoma.to/ebmyEPE","description":"One of the best places to go to, for a vibe, indie music, and some of the most amazing coffees. If you do come here do try the tarts.","reviewRating":{"@type":"Rating","ratingValue":5,"bestRating":5,"worstRating":0}},{"author":"Akash Negandhi","url":"https://www.zoma.to/MkdEkAL","description":"Enjoyed the whole experience! Special mention to Asif for catering us","reviewRating":{"@type":"Rating","ratingValue":5,"bestRating":5,"worstRating":0}}]}
#            </script>
#            <script data-rh="true" type="application/ld+json">
#             {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":0,"item":{"id":"https://www.zomato.com","name":"Home","url":"https://www.zomato.com"}},{"@type":"ListItem","position":1,"item":{"id":"https://www.zomato.com/india","name":"India","url":"https://www.zomato.com/india"}},{"@type":"ListItem","position":2,"item":{"id":"https://www.zomato.com/mumbai/restaurants","name":"Mumbai","url":"https://www.zomato.com/mumbai/restaurants"}},{"@type":"ListItem","position":3,"item":{"id":"https://www.zomato.com/mumbai/western-suburbs-restaurants","name":"Western Suburbs","url":"https://www.zomato.com/mumbai/western-suburbs-restaurants"}},{"@type":"ListItem","position":4,"item":{"id":"https://www.zomato.com/mumbai/juhu-restaurants","name":"Juhu","url":"https://www.zomato.com/mumbai/juhu-restaurants"}},{"@type":"ListItem","position":5,"item":{"id":"https://www.zomato.com/mumbai/restaurants/in/juhu-residency-boutique-hotel-juhu","name":"Juhu Residency Boutique Hotel, Juhu","url":"https://www.zomato.com/mumbai/restaurants/in/juhu-residency-boutique-hotel-juhu"}},{"@type":"ListItem","position":6,"item":{"id":"https://www.zomato.com/mumbai/ettarra-1-juhu","name":"Ettarra","url":"https://www.zomato.com/mumbai/ettarra-1-juhu"}},{"@type":"ListItem","position":7,"item":{"id":"","name":"Ettarra reviews","url":""}}]}
#            </script>
#            <style data-styled="fEZFGP gcZrSa gtpTvJ jNLiuV cpncwI etgVqV cleYUF bcvQIw jNQIAg JsGXp hPeKjm koDuiP gAkuDn jtRcBY htMNyq hUtowN bVMVXt ifdVMV gpdnUW bmbqmX hKuLnY kkPOQi fvCyAU lngwlA flDZqC gPfbnc fIVbKv cndLHu kAUthO kTLiBn dZLIze eAbcvW gAhmYY hwmUUw iFnyeo iRDDBk ezrcri kyPUnV iwHbVQ ffadyU kMNrPk fauQLv jKmKoK cvuzKA ldPnxs hKuwIZ eknwSb eKVQco fmXFvO dvaCaS dbaWnN jJsAxK hicrMn iVGoab iHOdZD hgBaks owXCG fkgPm cFjHTH haCKcB imaLvs jbMQQg dlAMFr gETRUR epCaSO jPHMbK kbtxDf kvZLLD gbMEMg iBDNjP euMcxD kJfdTE jATTyR gMhjmN eXjyot kGvkce fxuOHl cHwtYE hTyrOQ bOnRKS ciQEQt cFOKgK eVDQHB cqxheR cKptLg gIxuXV hUkOLL jGYPzd gNHSCq ieQgAk irTdAf gLYugy fPpMAv brTljW fwzNdh QvFZM clCBXa kHxpSk fGkaCs jcWdhP fzeTVA fhiOIU liCXOR cILgox pxJGx bzIMnO kEgyiI edgvoM dYrjiw cibBCi bFWudR gBMRZZ hAtIrI vNCcy dIdAej dEfcmc gGsJhe dfwCXs eCyXgR bAWgiD hHsuUf jWtszn jbECqP kvmhJa gTlqCK kEzEWS fBEbXA eOrynq eYLMaV fFFWNT bFxTMj kQDQPR eiMLBn jPTnRn ktGdJs ldrKZS kixkcO dsSqud cdVGts InUsv laEaUf KhrGw gZlEbV gMGrsY cRtKcd iBwqmB llmLSN devPDU jUYeEj eBYfoo bhdCHn hZfvWQ OgtQR fKvqMN dItmfd uYlzc fBRBzM bAbxym iykkZs bALPVL gMgUhR dqJnoA iDFbjF hWkbSv kjLqhb chXscW hXbQPj cjGwCG dXXDbl eiXHLY dkwpEa lcRQkc eaqKit kPLwps fIuLDK kUZAII kvUFhz jfiZBb DwRag bfhkN iMLxEB dLJXNs huDXWU ZllRT gASpnQ bPREJm bBMYAx bUDJrO HMePy cFoaqc iDhKpo ubVlf bUeOFu yWOOM eyzWaX FXJYc fFbthI huZFkM cYqyvY fgKeBV bGfHbP gzcbGg ixsoFB cvsUXu cDEyWL jPUyxY gJYvaX ceanFw jzrEzn erXsJY oEoRv iYiNyG fYFzFe hVtcrz DHMyd ehBfFg mtUrN dirNi epQgJy fyCgPB iFttwN jNqlkW bvogHW iWeJHV kVcJCg dOFWhj iMPEip btDUHh llOEHd jWound dLsZWW jYhtHx gQXbfm iFsnCv iDzUMo dxcfRo gfYSur HEzmM fvpjYk RAjVl jBOGYb eHuOnX blTnzu bskCAo kBllqA fFZiud hUHYzH" data-styled-version="4.4.1">
#             /* sc-component-id: sc-1kx5g6g-1 */
# .dXXDbl{min-width:auto;min-height:36px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;border-radius:0.6rem;background:transparent;padding:0;border:none;cursor:pointer;} .dXXDbl:focus,.dXXDbl:active{outline:none;box-shadow:none;}
# /* sc-component-id: sc-1kx5g6g-2 */
# .eiXHLY{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:middle;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:100%;width:100%;min-width:auto;min-height:36px;line-height:36px;margin-top:0;margin-left:0;outline:none !important;white-space:nowrap;font-size:1.4rem;font-weight:300;background:transparent;border-color:#FF7E8B;border-width:0.1rem;border-style:solid;border-radius:0.6rem;color:#EF4F5F;padding:0 1.6rem;opacity:1;background-clip:border-box;-webkit-transition:-webkit-transform 0.25s,opacity 0.25s,box-shadow 0.25s ease;-webkit-transition:transform 0.25s,opacity 0.25s,box-shadow 0.25s ease;transition:transform 0.25s,opacity 0.25s,box-shadow 0.25s ease;} .eiXHLY > *:not(:last-child):not(:only-child){margin-right:0.8rem;line-height:1;} .sc-1kx5g6g-1:focus .eiXHLY{color:#BF2938;background:rgba(239,79,95,0.04);border-color:#E03546;box-shadow:0 0 0 4px #fff,0 0 0 5px #717171,0 0 0 6px rgba(255,255,255,0.5);} .eiXHLY:not(:-moz-focusring):focus{box-shadow:none;} .sc-1kx5g6g-1:active .eiXHLY{background:rgba(239,79,95,0.16);border-color:#E03546;outline:none;box-shadow:unset;} @media (hover:hover){.eiXHLY .sc-1kx5g6g-1:hover,.eiXHLY .sc-1kx5g6g-1:focus{color:#BF2938;background:rgba(239,79,95,0.04);border-color:#E03546;}.eiXHLY:hover{color:#BF2938;background:rgba(239,79,95,0.04);border-color:#E03546;}.eiXHLY:hover i{-webkit-transform:translate(-4px,0);-ms-transform:translate(-4px,0);transform:translate(-4px,0);}} @media (hover:none){.sc-1kx5g6g-1:focus .eiXHLY{outline:none;box-shadow:none !important;}} @media (max-width:480px){.eiXHLY{position:relative;overflow:hidden;}.eiXHLY:after{content:"";display:block;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%) scale(0);-ms-transform:translate(-50%,-50%) scale(0);transform:translate(-50%,-50%) scale(0);width:50rem;height:50rem;background-color:#EF4F5F;border-radius:100%;opacity:0.6;}.eiXHLY:not(:active):after{-webkit-animation:bXTtfc 1s ease-out;animation:bXTtfc 1s ease-out;}.eiXHLY:after{visibility:hidden;}.eiXHLY:focus:after{visibility:visible;}}
# /* sc-component-id: sc-1kx5g6g-3 */
# .dkwpEa{display:inline-block;vertical-align:middle;line-height:normal;font-size:inherit;-webkit-transition:-webkit-transform 0.4s;-webkit-transition:transform 0.4s;transition:transform 0.4s;} .dkwpEa *:last-child:not(:only-child){margin-top:0.1rem;}
# /* sc-component-id: sc-rbbb40-0 */
# .iRDDBk{display:inline-block;vertical-align:middle;line-height:1;width:20px;height:20px;}.ezrcri{display:inline-block;vertical-align:middle;line-height:1;width:12px;height:12px;}.kyPUnV{display:inline-block;vertical-align:middle;line-height:1;width:14px;height:14px;}.iwHbVQ{display:inline-block;vertical-align:middle;line-height:1;width:18px;height:18px;}.ffadyU{display:inline-block;vertical-align:middle;line-height:1;width:1rempx;height:1rempx;}.kMNrPk{display:inline-block;vertical-align:middle;line-height:1;width:16px;height:16px;}.fauQLv{display:inline-block;vertical-align:middle;line-height:1;width:0.8rempx;height:0.8rempx;}.jKmKoK{display:inline-block;vertical-align:middle;line-height:1;width:15px;height:15px;}.cvuzKA{display:inline-block;vertical-align:middle;line-height:1;width:22px;height:22px;}
# /* sc-component-id: sc-rbbb40-1 */
# .iFnyeo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:inherit;}
# /* sc-component-id: sc-1hez2tp-0 */
# .OgtQR{font-size:1.8rem;line-height:1.5;margin:0 0;color:#363636;}.fKvqMN{font-size:1.4rem;line-height:1.5;margin:0 0;color:#9C9C9C;}
# /* sc-component-id: sc-1ly0uwc-0 */
# .htMNyq{background:#E23744;top:0;pointer-events:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;height:2px;z-index:20000000;position:fixed;left:0;width:0;opacity:1;contain:content;-webkit-transform:scaleX(1);-ms-transform:scaleX(1);transform:scaleX(1);-webkit-transform-origin:left;-ms-transform-origin:left;transform-origin:left;-webkit-animation:dbnfkf 2s cubic-bezier(0.65,0.05,0.36,1) forwards;animation:dbnfkf 2s cubic-bezier(0.65,0.05,0.36,1) forwards;will-change:transform;}
# /* sc-component-id: sc-bke1zw-0 */
# .fIuLDK{width:100%;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}
# /* sc-component-id: sc-bke1zw-1 */
# .kUZAII{position:relative;width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;max-width:33.33333333333333%;padding:0 0px 8px 0px;}.kvUFhz{position:relative;width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;max-width:41.66666666666667%;padding:0 2.5px 5px 0px;} @media (max-width:768px) and (min-width:481px){.kvUFhz{max-width:33.33333333333333%;padding:0 2.5px 5px 0px;}} @media (max-width:480px){.kvUFhz{padding:0 2.5px 5px 0px;max-width:50%;}}.jfiZBb{position:relative;width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;max-width:41.66666666666667%;padding:0 0px 5px 2.5px;} @media (max-width:768px) and (min-width:481px){.jfiZBb{max-width:33.33333333333333%;padding:0 0px 5px 2.5px;}} @media (max-width:480px){.jfiZBb{padding:0 0px 5px 2.5px;max-width:50%;}}
# /* sc-component-id: sc-s1isp7-0 */
# .cHwtYE{position:absolute;top:0;background-image:url(https://b.zmtcdn.com/data/pictures/5/20468935/f69c55e3ec29f67bd6ba2eab04807ec8.jpg?fit=around|51.45:27.75&crop=51.45:27.75;*,*);width:100%;height:100%;background-size:cover;-webkit-filter:blur(10px);filter:blur(10px);}.hTyrOQ{position:absolute;top:0;background-image:url(https://b.zmtcdn.com/data/pictures/chains/5/20468935/eb6d453b422c24f2c9b08862878c73a5.jpg?fit=around|20:18.2&crop=20:18.2;*,*);width:100%;height:100%;background-size:cover;-webkit-filter:blur(10px);filter:blur(10px);}.bOnRKS{position:absolute;top:0;background-image:url(https://b.zmtcdn.com/data/pictures/chains/5/20468935/0c3a3e025f91b5a0e9268d6c9f28c175.jpg?fit=around|20:18.2&crop=20:18.2;*,*);width:100%;height:100%;background-size:cover;-webkit-filter:blur(10px);filter:blur(10px);}.ciQEQt{position:absolute;top:0;background-image:url(https://b.zmtcdn.com/data/pictures/chains/5/20468935/bd2771c3c0c0aa5a0c3566a9112405a6.jpg?fit=around|20:18.2&crop=20:18.2;*,*);width:100%;height:100%;background-size:cover;-webkit-filter:blur(10px);filter:blur(10px);}
# /* sc-component-id: sc-s1isp7-1 */
# .gMhjmN{position:relative;max-width:100%;width:100%;height:100%;overflow:hidden;}.eXjyot{position:relative;max-width:100%;width:4.4rem;height:4.4rem;overflow:hidden;}.kGvkce{position:relative;max-width:100%;width:100%;height:15rem;overflow:hidden;}.fxuOHl{position:relative;max-width:100%;width:13.7rem;height:4rem;overflow:hidden;}
# /* sc-component-id: sc-s1isp7-3 */
# .dqJnoA{width:100%;position:absolute;top:0;left:0;height:100%;background:#F8F8F8;background-image:linear-gradient( to right,#F8F8F8 0%,#FFFFFF 10%,#F8F8F8 40%,#F8F8F8 100% );background-repeat:no-repeat;opacity:1;-webkit-transition:opacity 0.25s ease-out;transition:opacity 0.25s ease-out;will-change:opacity;border-radius:inherit;-webkit-animation:jCOzbu 1.5s infinite linear forwards;animation:jCOzbu 1.5s infinite linear forwards;}
# /* sc-component-id: sc-s1isp7-5 */
# .cFOKgK{width:100%;height:100%;object-fit:cover;-webkit-transform:none;-ms-transform:none;transform:none;opacity:0;will-change:transform,opacity;border-radius:inherit;-webkit-filter:brightness(0.95);filter:brightness(0.95);-webkit-transition:-webkit-transform 0.4s ease-in-out,opacity 1.63s ease,filter 0.4s ease;-webkit-transition:transform 0.4s ease-in-out,opacity 1.63s ease,filter 0.4s ease;transition:transform 0.4s ease-in-out,opacity 1.63s ease,filter 0.4s ease;} .cFOKgK:hover{-webkit-transform:scale(1.05);-ms-transform:scale(1.05);transform:scale(1.05);-webkit-filter:brightness(1.05);filter:brightness(1.05);} .cFOKgK img:not([src]):not([srcset]){visibility:hidden;} @-moz-document url-prefix(){.cFOKgK img:-moz-loading{visibility:hidden;}}.eVDQHB{width:100%;height:100%;object-fit:cover;-webkit-transform:none;-ms-transform:none;transform:none;opacity:0;will-change:transform,opacity;border-radius:inherit;-webkit-filter:unset;filter:unset;-webkit-transition:opacity 1.63s ease,-webkit-transform 0.25s ease;-webkit-transition:opacity 1.63s ease,transform 0.25s ease;transition:opacity 1.63s ease,transform 0.25s ease;} .eVDQHB img:not([src]):not([srcset]){visibility:hidden;} @-moz-document url-prefix(){.eVDQHB img:-moz-loading{visibility:hidden;}}.cqxheR{width:100%;height:100%;object-fit:cover;-webkit-transform:scale(0.9);-ms-transform:scale(0.9);transform:scale(0.9);opacity:0;will-change:transform,opacity;border-radius:inherit;-webkit-filter:unset;filter:unset;-webkit-transition:opacity 0.25s ease,-webkit-transform 0.25s ease;-webkit-transition:opacity 0.25s ease,transform 0.25s ease;transition:opacity 0.25s ease,transform 0.25s ease;} .cqxheR img:not([src]):not([srcset]){visibility:hidden;} @-moz-document url-prefix(){.cqxheR img:-moz-loading{visibility:hidden;}}.cKptLg{width:100%;height:100%;object-fit:cover;-webkit-transform:scale(0.9);-ms-transform:scale(0.9);transform:scale(0.9);opacity:0;will-change:transform,opacity;border-radius:inherit;-webkit-filter:brightness(0.95);filter:brightness(0.95);-webkit-transition:-webkit-transform 0.4s ease-in-out,filter 0.4s ease,opacity 0.25s ease;-webkit-transition:transform 0.4s ease-in-out,filter 0.4s ease,opacity 0.25s ease;transition:transform 0.4s ease-in-out,filter 0.4s ease,opacity 0.25s ease;} .cKptLg:hover{-webkit-transform:scale(1.05);-ms-transform:scale(1.05);transform:scale(1.05);-webkit-filter:brightness(1.05);filter:brightness(1.05);} .cKptLg img:not([src]):not([srcset]){visibility:hidden;} @-moz-document url-prefix(){.cKptLg img:-moz-loading{visibility:hidden;}}
# /* sc-component-id: sc-18n4g8v-0 */
# .gAhmYY{width:-webkit-max-content;width:-moz-max-content;width:max-content;}.hwmUUw{width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}
# /* sc-component-id: sc-qnejpk-0 */
# .uYlzc{position:absolute;top:5.8rem;width:100%;border-radius:0.6rem;background:#FFFFFF;box-shadow:0px 1px 8px rgba(28,28,28,0.15);z-index:10;opacity:0;-webkit-transition:opacity,-webkit-transform 0.25s ease;-webkit-transition:opacity,transform 0.25s ease;transition:opacity,transform 0.25s ease;-webkit-transform:translateY(-1rem);-ms-transform:translateY(-1rem);transform:translateY(-1rem);} @media (max-width:480px){.uYlzc{top:5.8rem;}}
# /* sc-component-id: sc-qnejpk-4 */
# .dItmfd{-webkit-transform:none;-ms-transform:none;transform:none;-webkit-transition:-webkit-transform 0.25s;-webkit-transition:transform 0.25s;transition:transform 0.25s;}
# /* sc-component-id: sc-qnejpk-6 */
# .bhdCHn{margin-left:0;margin-top:0;color:#CFCFCF;font-size:1.8rem;font-weight:300;overflow:hidden;text-overflow:ellipsis;} @media (max-width:480px){.bhdCHn{font-size:1.8rem;}}.hZfvWQ{margin-left:1rem;margin-top:0;color:#CFCFCF;font-size:1.8rem;font-weight:300;overflow:hidden;text-overflow:ellipsis;} @media (max-width:480px){.hZfvWQ{font-size:1.8rem;}}
# /* sc-component-id: sc-qnejpk-7 */
# .jUYeEj{margin:0 2rem 0 0;width:inherit;}
# /* sc-component-id: sc-qnejpk-8 */
# .eBYfoo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;overflow:hidden;white-space:nowrap;-webkit-box-pack:unset;-webkit-justify-content:unset;-ms-flex-pack:unset;justify-content:unset;}
# /* sc-component-id: sc-qnejpk-9 */
# .devPDU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;padding:1rem 0;font-size:18px;height:4.8rem;border:none;border-radius:0.6rem;cursor:pointer;background:#fff;} @media (max-width:480px){.devPDU{height:4.8rem;}}
# /* sc-component-id: sc-qnejpk-11 */
# .llmLSN{position:relative;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}
# /* sc-component-id: sc-iyc8of-0 */
# .bAWgiD{position:relative;display:inline-block;padding:0;cursor:pointer;width:-webkit-max-content;width:-moz-max-content;width:max-content;}
# /* sc-component-id: sc-kZmsYB */
# .ieQgAk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%;} @media (max-width:480px){.ieQgAk{padding:0 0 0 1rem;}}
# /* sc-component-id: sc-RcBXQ */
# .irTdAf{margin-top:1rem;width:100%;} @media (max-width:480px){.irTdAf{margin-top:1rem;}}
# /* sc-component-id: sc-iSDuPN */
# .fwzNdh{font-size:4.4rem;line-height:1.2;font-weight:400;color:#1C1C1C;margin:0;font-weight:500;font-size:3.6rem;cursor:pointer;} @media (max-width:480px){.fwzNdh{font-size:2.4rem;}}
# /* sc-component-id: sc-fQejPQ */
# .bFWudR{font-size:1.8rem;line-height:1.5;color:#828282;margin-top:0.5rem;}
# /* sc-component-id: sc-clNaTc */
# .vNCcy{-webkit-text-decoration:none;text-decoration:none;font-size:1.6rem;color:#9C9C9C;} .vNCcy:hover{color:#696969;} @media (max-width:480px){.vNCcy{font-size:1.2rem;}}
# /* sc-component-id: sc-etwtAo */
# .dIdAej{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;margin-top:0.5rem;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-transition:opacity 0.2s ease-in-out;transition:opacity 0.2s ease-in-out;} @media (max-width:480px){.dIdAej{width:100%;}}
# /* sc-component-id: sc-jXQZqI */
# .dEfcmc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-transition:opacity 0.2s ease-in-out;transition:opacity 0.2s ease-in-out;} @media (max-width:480px){.dEfcmc{width:100%;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}}
# /* sc-component-id: sc-iGPElx */
# .gGsJhe{color:#F4A266;font-size:1.4rem;line-height:1.5;} @media (max-width:480px){.gGsJhe{font-size:1.2rem;}}
# /* sc-component-id: sc-kasBVs */
# .dfwCXs{color:#828282;font-size:1.4rem;line-height:1.5;} .dfwCXs:before{content:'-';margin:0 1rem;} @media (max-width:480px){.dfwCXs{font-size:1.2rem;}.dfwCXs:before{content:'-';margin:0 1rem;}}
# /* sc-component-id: sc-hgHYgh */
# .eCyXgR{font-size:1.8rem;line-height:2.4rem;}
# /* sc-component-id: sc-eInJlc */
# .hHsuUf{margin-left:0.8rem;}
# /* sc-component-id: sc-fOICqy */
# .fPpMAv{width:100%;} @media (max-width:480px){.fPpMAv{padding-right:0.5rem;}}
# /* sc-component-id: sc-hzDEsm */
# .gLYugy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;} @media (max-width:480px){.gLYugy{-webkit-align-items:end;-webkit-box-align:end;-ms-flex-align:end;align-items:end;}}
# /* sc-component-id: sc-jeCdPy */
# .brTljW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}
# /* sc-component-id: sc-fgfRvd */
# @media (max-width:480px){.gBMRZZ{line-height:1.2;}}
# /* sc-component-id: sc-hIVACf */
# .hAtIrI{color:#696969;display:inline;-webkit-text-decoration:none;text-decoration:none;} .hAtIrI:hover{color:#363636;} @media (max-width:480px){.hAtIrI{font-size:1.4rem;font-weight:400;}}
# /* sc-component-id: sc-1q7bklc-1 */
# .cILgox{margin-right:0.2rem;font-weight:600;font-size:inherit;padding-bottom:0.1rem;}
# /* sc-component-id: sc-1q7bklc-2 */
# .pxJGx{margin-left:0;}
# /* sc-component-id: sc-1q7bklc-5 */
# .clCBXa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:inherit;cursor:pointer;}.kHxpSk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:inherit;cursor:unset;}
# /* sc-component-id: sc-1q7bklc-6 */
# .liCXOR{display:block;font-size:inherit;}
# /* sc-component-id: sc-1q7bklc-7 */
# .bzIMnO{display:block;font-size:inherit;margin-left:0.8rem;}
# /* sc-component-id: sc-1q7bklc-8 */
# .kEgyiI{font-weight:600;font-size:1.4rem;line-height:1.8rem;padding-bottom:0;border-bottom:unset;color:#363636;} @media (max-width:480px){.kEgyiI{font-weight:500;font-size:1.2rem;line-height:1.2rem;}}
# /* sc-component-id: sc-1q7bklc-9 */
# .edgvoM{font-weight:400;font-size:1.2rem;line-height:1.6rem;padding-bottom:0.2rem;border-bottom:0.5px dashed #B5B5B5;color:#363636;} @media (max-width:480px){.edgvoM{font-size:1.1rem;line-height:1.1rem;}}.dYrjiw{font-weight:400;font-size:1.2rem;line-height:1.6rem;padding-bottom:0;border-bottom:unset;color:#363636;} @media (max-width:480px){.dYrjiw{font-size:1.1rem;line-height:1.1rem;}}
# /* sc-component-id: sc-1q7bklc-10 */
# .fGkaCs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#0E5020;color:#FFFFFF;height:2.6rem;min-width:3.0rem;padding:0 0.4rem;font-size:17px;border-radius:0.6rem;border:1px solid #0E5020;}.jcWdhP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#267E3E;color:#FFFFFF;height:2.6rem;min-width:3.0rem;padding:0 0.4rem;font-size:17px;border-radius:0.6rem;border:1px solid #267E3E;}.fzeTVA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#0E5020;color:#FFFFFF;height:2rem;min-width:2.6rem;padding:0 0.4rem;font-size:1.3rem;border-radius:0.6rem;border:1px solid #0E5020;}.fhiOIU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#3AB757;color:#FFFFFF;height:2rem;min-width:2.6rem;padding:0 0.4rem;font-size:1.3rem;border-radius:0.6rem;border:1px solid #3AB757;}
# /* sc-component-id: sc-dxZgTM */
# .QvFZM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:end;-webkit-box-align:end;-ms-flex-align:end;align-items:end;} @media (max-width:480px){.QvFZM{padding-right:1rem;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-bottom:1.2rem;margin-top:1rem;}}
# /* sc-component-id: sc-iomxrj */
# .cibBCi{width:4rem;}
# /* sc-component-id: sc-dRaagA */
# .jtRcBY{height:3px;}
# /* sc-component-id: sc-fEUNkw */
# .gAkuDn{position:relative;}
# /* sc-component-id: sc-dREXXX */
# .fEZFGP{position:fixed;top:0;left:0;width:100%;height:100%;min-width:-webkit-max-content;min-width:-moz-max-content;min-width:max-content;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;overflow:auto;z-index:1002;font-size:1.6rem;}
# /* sc-component-id: sc-kcbnda */
# .gcZrSa{position:fixed;top:0;left:0;width:100%;height:100%;background-color:#1c1c1c;opacity:0.85;visibility:visible;-webkit-transition:opacity 0.25s ease 0s;transition:opacity 0.25s ease 0s;}
# /* sc-component-id: sc-hcmgZB */
# .gtpTvJ{position:absolute;bottom:0;width:100vw;min-height:0;-webkit-transition:all 0.25s ease 0s,visibility 0s ease 0s;transition:all 0.25s ease 0s,visibility 0s ease 0s;border-radius:0.6rem 0.6rem 0 0;background-color:#ffffff;height:-webkit-max-content;height:-moz-max-content;height:max-content;-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);opacity:1;z-index:1;display:block;}
# /* sc-component-id: sc-dHmInP */
# .jNLiuV{min-height:8rem;display:block;overflow:initial;}
# /* sc-component-id: sc-ejGVNB */
# .cpncwI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;}
# /* sc-component-id: sc-eLdqWK */
# .bcvQIw{font-size:1.6rem;font-weight:600;}
# /* sc-component-id: sc-iiUIRa */
# .jNQIAg{font-size:1.4rem;font-weight:400;margin-top:0.5rem;}
# /* sc-component-id: sc-hgRTRy */
# .etgVqV{width:100vw;object-fit:fill;position:relative;border-radius:1.2rem 1.2rem 0 0;aspect-ratio:375/150;}
# /* sc-component-id: sc-iIHSe */
# .cleYUF{width:70%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:absolute;right:0;top:25%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);padding:2rem;color:black;}
# /* sc-component-id: sc-gldTML */
# .koDuiP{font-weight:600;font-size:1.4rem;line-height:2.4rem;color:#ef4f5f;display:grid;place-items:center;} @media (max-height:700px){.koDuiP{margin-bottom:3rem;}}
# /* sc-component-id: sc-feryYK */
# .hPeKjm{width:-webkit-fill-available;width:-moz-available;width:fill-available;border-radius:0.6rem;display:grid;place-items:center;margin:2.5rem 2rem 2rem;padding:1.2rem;font-size:1.6rem;background:#ef4f5f;color:white;} @media (max-height:700px){.hPeKjm{font-size:1.4rem;margin:2rem 1.5rem 1.5rem;padding:1rem;}}
# /* sc-component-id: sc-cJOK */
# .JsGXp{padding:0 1.6rem 1.6rem;width:100%;}
# /* sc-component-id: sc-3o0n99-0 */
# .hKuLnY{width:2rem;height:1.5rem;position:relative;-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);-webkit-transition:-webkit-transform 0.15s ease-in-out;-webkit-transition:transform 0.15s ease-in-out;transition:transform 0.15s ease-in-out;cursor:pointer;opacity:0;pointer-events:none;} @media screen and (max-width:768px){.hKuLnY{opacity:1;pointer-events:all;}.hKuLnY > span{background:#1C1C1C;}}
# /* sc-component-id: sc-3o0n99-1 */
# .kkPOQi{-webkit-transform-origin:left center;-ms-transform-origin:left center;transform-origin:left center;display:block;position:absolute;cursor:pointer;height:3px;width:100%;border-radius:0;opacity:1;left:0;-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);-webkit-transition:-webkit-transform 0.15s ease-in-out,all 0.15s linear;-webkit-transition:transform 0.15s ease-in-out,all 0.15s linear;transition:transform 0.15s ease-in-out,all 0.15s linear;} .kkPOQi:nth-child(1){top:0;} .kkPOQi:nth-child(2){top:0.6rem;} .kkPOQi:nth-child(3){top:1.2rem;}
# /* sc-component-id: sc-3o0n99-3 */
# .fIVbKv{width:100%;list-style:none;max-width:100%;height:72px;padding-top:1.5rem;padding-bottom:1.7rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;background:transparent;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-ms-flex-pack:justify;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;opacity:1;-webkit-transition-delay:0s;transition-delay:0s;padding:1.7rem 0;margin:0;-webkit-transition:opacity 0.25s linear,visibility 0.25s linear,height 0.25s cubic-bezier(0.52,0.16,0.24,1);transition:opacity 0.25s linear,visibility 0.25s linear,height 0.25s cubic-bezier(0.52,0.16,0.24,1);} .fIVbKv > *{margin-right:2rem;} .fIVbKv > *:last-child{margin-right:0;} @media screen and (max-width:768px){.fIVbKv{height:0;visibility:hidden;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:absolute;width:100%;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;background:#FFFFFF;top:99%;left:0;margin:0;padding:0;-webkit-transition:height 0.25s cubic-bezier(0.52,0.16,0.24,1);transition:height 0.25s cubic-bezier(0.52,0.16,0.24,1);}.fIVbKv > *{margin-right:0;}}
# /* sc-component-id: sc-3o0n99-4 */
# .cndLHu{padding-bottom:1rem;border-radius:0;box-sizing:border-box;border-style:solid;border-color:transparent;border-width:0;border-bottom-width:0.2rem;} .cndLHu > *{margin-right:1.8rem;} .cndLHu > *:last-child{margin-right:0;} .cndLHu:focus,.cndLHu:active{outline:none;} .cndLHu:not(:-moz-focusring):focus{box-shadow:none;} @media (hover:none){.cndLHu{box-shadow:none;outline:none;}} @media screen and (max-width:768px){.cndLHu{margin-bottom:3.5rem;width:100%;opacity:0;-webkit-transition:opacity 0.25s linear;transition:opacity 0.25s linear;}.cndLHu:nth-last-child{margin-bottom:0;}.cndLHu > *{margin-right:0;}}.kAUthO{padding-bottom:0;border-radius:0;box-sizing:border-box;border-style:solid;border-color:transparent;border-width:0;border-bottom-width:0.2rem;} .kAUthO > *{margin-right:1.8rem;} .kAUthO > *:last-child{margin-right:0;} .kAUthO:focus,.kAUthO:active{outline:none;} .kAUthO:not(:-moz-focusring):focus{box-shadow:none;} @media (hover:none){.kAUthO{box-shadow:none;outline:none;}} @media screen and (max-width:768px){.kAUthO{margin-bottom:3.5rem;width:100%;opacity:0;-webkit-transition:opacity 0.25s linear;transition:opacity 0.25s linear;}.kAUthO:nth-last-child{margin-bottom:0;}.kAUthO > *{margin-right:0;}}
# /* sc-component-id: sc-yvzia9-1 */
# .bVMVXt{width:100%;max-width:100%;display:block;position:static;height:7.2rem;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;top:0;-webkit-transition:opacity 0.25s linear,height 0.56s cubic-bezier(0.52,0.16,0.24,1);transition:opacity 0.25s linear,height 0.56s cubic-bezier(0.52,0.16,0.24,1);background-color:transparent;} @media (min-width:768px) and (max-width:900px){.bVMVXt{padding:0 1.5rem;}}
# /* sc-component-id: sc-yvzia9-2 */
# .ifdVMV{width:100%;max-width:110rem;padding-right:0;margin:0 auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;height:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;z-index:4;}
# /* sc-component-id: sc-yvzia9-3 */
# .gpdnUW{display:none;height:7.2rem;overflow:hidden;position:absolute;width:100%;margin:0;padding:0 1.5rem;background:transparent;} @media screen and (max-width:768px){.gpdnUW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;z-index:4;}}
# /* sc-component-id: sc-yvzia9-4 */
# .bmbqmX{display:none;z-index:2;height:100%;width:auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;border-bottom:none;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: sc-yvzia9-5 */
# .flDZqC{max-width:14rem;height:2.7rem;display:block;cursor:pointer;} .flDZqC:focus{outline:none;} @media screen and (max-width:768px){.flDZqC{display:none;}}
# /* sc-component-id: sc-yvzia9-7 */
# .fvCyAU{max-width:14rem;display:block;cursor:pointer;display:none;} .fvCyAU:focus{outline:none;} @media screen and (max-width:768px){.fvCyAU{display:none;}} @media screen and (max-width:768px){.fvCyAU{display:block;cursor:pointer;}}
# /* sc-component-id: sc-eEieub */
# .gPfbnc{width:100%;}
# /* sc-component-id: sc-keFjpB */
# .owXCG{width:100%;background:#FFFFFF;z-index:10;} @media (min-width:481px){.owXCG{max-height:60rem;border-radius:0.8rem;position:absolute;overflow:auto;top:3rem;visibility:hidden;opacity:0;border:1px solid #CFCFCF;box-shadow:0px 2px 8px rgba(28,28,28,0.08);-webkit-transition:opacity 0.25s ease,top 0.25s ease;transition:opacity 0.25s ease,top 0.25s ease;padding:1.6rem 0;}}
# /* sc-component-id: sc-cCbXAZ */
# .iHOdZD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:6rem;margin:-1px;margin-right:-0.6rem;}
# /* sc-component-id: sc-fHSTwm */
# @media (min-width:481px){.iVGoab{border-radius:0.8rem;width:53rem;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;}} @media (max-width:480px){.iVGoab{width:100%;border:none;border-radius:0;}}
# /* sc-component-id: sc-cmIlrE */
# .hgBaks{border:none;font-size:1.4rem;width:100%;border-radius:0.8rem;}
# /* sc-component-id: sc-gleUXh */
# .hicrMn{width:0rem;height:2rem;border:0.05rem solid #CFCFCF;}
# /* sc-component-id: sc-doWzTn */
# .dZLIze{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:5.4rem;background:#FFFFFF;border-radius:0.8rem;box-shadow:0px 2px 8px rgba(28,28,28,0.08);border:1px solid #E8E8E8;}
# /* sc-component-id: sc-hARARD */
# .kTLiBn{width:64%;position:absolute;top:0;left:47%;-webkit-transform:translate(-50%,0.8rem);-ms-transform:translate(-50%,0.8rem);transform:translate(-50%,0.8rem);}
# /* sc-component-id: sc-ccLTTT */
# .fkgPm{font-size:1.8rem;line-height:1.5;text-align:right;vertical-align:middle;font-weight:300;color:#696969;cursor:pointer;padding:0.8rem !important;border-radius:0.6rem;vertical-align:middle;background:transparent;} .fkgPm:hover{color:#1C1C1C;} .fkgPm:active,.fkgPm:hover:active{color:#1C1C1C;border-bottom-color:#EF4F5F;outline:none;} .fkgPm:focus,.fkgPm:active{outline:none;} .sc-3o0n99-4:focus > .fkgPm{box-shadow:#E23744 0px 0px 1px 1px !important;} @media screen and (max-width:768px){.fkgPm{color:#696969;border-radius:0;border-width:0;border-color:transparent;}.fkgPm:hover{color:#1C1C1C;}}
# /* sc-component-id: sc-hlILIN */
# .hUtowN{box-shadow:inset 0px -0.5px 0px #E8E8E8;}
# /* sc-component-id: sc-bJHhxl */
# .eKVQco{cursor:pointer;background:#FFFFFF;box-shadow:inset 0px -0.5px 0px #E8E8E8;padding:1.8rem 1.8rem 1.8rem 1.5rem;} .eKVQco:hover{background:#F8F8F8;} @media (max-width:480px){.eKVQco{padding:0.6rem 0 1.2rem 0;}}
# /* sc-component-id: sc-fCPvlr */
# .dbaWnN{font-size:inherit;line-height:1.5;margin:0 0;color:#EF4F5F;font-size:1.7rem;font-weight:400;text-align:left;}
# /* sc-component-id: sc-hAXbOi */
# .jJsAxK{font-size:inherit;line-height:1.5;margin:0 0;color:#363636;font-size:1.3rem;margin-left:2.6rem;color:#9C9C9C;text-align:left;}
# /* sc-component-id: sc-cCVOAp */
# .eknwSb{width:36rem;max-height:45rem;background:white;border-radius:0.8rem;position:absolute;left:0;overflow:auto;border:1px solid #CFCFCF;box-shadow:0px 2px 8px rgba(28,28,28,0.08);top:3rem;visibility:hidden;opacity:0;-webkit-transition:opacity 0.25s ease,top 0.25s ease;transition:opacity 0.25s ease,top 0.25s ease;z-index:10;} @media (max-width:480px){.eknwSb{border:0;border-radius:0;overflow:auto;position:static;left:0;top:0;visibility:visible;opacity:1;-webkit-transition:none;transition:none;height:auto;box-shadow:none;max-height:unset;width:100%;}}
# /* sc-component-id: sc-hCaUpS */
# .fmXFvO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-weight:500;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-sPYgB */
# .dvaCaS{width:2.6rem;}
# /* sc-component-id: sc-bYnzgO */
# .hKuwIZ{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);-webkit-transition:-webkit-transform 0.25s ease-in-out;-webkit-transition:transform 0.25s ease-in-out;transition:transform 0.25s ease-in-out;cursor:pointer;}
# /* sc-component-id: sc-cPuPxo */
# .eAbcvW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;position:relative;height:100%;width:-webkit-max-content;width:-moz-max-content;width:max-content;border-radius:0.8rem;padding:0 1rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-hvvHee */
# .ldPnxs{border:none;font-size:1.4rem;margin:0 1rem 0 0.5rem;}
# /* sc-component-id: sc-DNdyV */
# .gNHSCq{position:-webkit-sticky;position:sticky;top:0;z-index:3;background:#FFFFFF;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;width:100%;} @media (min-width:481px) and (max-width:768px){.gNHSCq{padding:0 1rem;}} @media (min-width:769px){.gNHSCq{width:calc(100% + 1rem);padding-right:1rem;}} @media (max-width:480px){.gNHSCq{padding-bottom:1rem;}}
# /* sc-component-id: sc-geAPOV */
# .eOrynq{max-width:100%;-webkit-transform:translateZ(0px);-ms-transform:translateZ(0px);transform:translateZ(0px);-webkit-transition:-webkit-transform 0.2s ease-in-out;-webkit-transition:transform 0.2s ease-in-out;transition:transform 0.2s ease-in-out;}
# /* sc-component-id: sc-1y3q50z-0 */
# .bFxTMj{width:100%;max-width:110rem;overflow-y:hidden;overflow-x:auto;overflow:-moz-scrollbars-none;-ms-overflow-style:none;min-height:6.2rem;position:relative;} .bFxTMj::-webkit-scrollbar{display:none;}
# /* sc-component-id: sc-1y3q50z-1 */
# .kQDQPR{width:-webkit-max-content;width:-moz-max-content;width:max-content;min-width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;background-color:transparent;overflow:-moz-scrollbars-none;overflow-x:auto;-ms-overflow-style:none;} .kQDQPR::-webkit-scrollbar{display:none;} .kQDQPR:last-child{margin-right:0;padding-right:0;} .kQDQPR:first-child{margin-left:0;padding-left:0;}
# /* sc-component-id: sc-1y3q50z-2 */
# .InUsv{width:calc(100% - 2px);height:0rem;border-top:2px solid #CFCFCF;border-bottom:none;bottom:1px;left:0;margin:0;padding:0;position:absolute;} @media screen and (min-width:768px){.InUsv{min-width:calc(100% - 2px);}}
# /* sc-component-id: sc-1y3q50z-3 */
# .eiMLBn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;max-height:100%;margin-right:2rem;cursor:pointer;} .eiMLBn:nth-last-child(2){margin-right:0;} .eiMLBn:focus,.eiMLBn:active{outline:none;border:none;}
# /* sc-component-id: sc-1y3q50z-4 */
# ...
#              </path>
#             </svg>
#            </i>
#           </div>
#          </a>
#          <a class="sc-elhb8j-17 iDzUMo" href="https://www.facebook.com/zomato" target="_blank">
#           <div class="sc-elhb8j-7 jBOGYb">
#            <i class="sc-rbbb40-1 iFnyeo" color="#1C1C1C" size="22">
#             <svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="sc-rbbb40-0 cvuzKA" fill="#1C1C1C" height="22" role="img" viewbox="0 0 20 20" width="22" xmlns="http://www.w3.org/2000/svg">
#              <path d="M0 10C0 4.5 4.5 0 10 0C15.5 0 20 4.5 20 10C20 15.5 15.5 20 10 20C4.5 20 0 15.5 0 10ZM10.75 15.4375V10.1875H12.1875L12.375 8.375H10.75V7.5C10.75 7.0625 10.8125 6.8125 11.5 6.8125H12.375V5H10.9375C9.1875 5 8.625 5.875 8.625 7.3125V8.375H7.5V10.1875H8.5625V15.4375C8.5625 15.4375 10.75 15.4375 10.75 15.4375Z">
#              </path>
#             </svg>
#            </i>
#           </div>
#          </a>
#         </div>
#         <div class="sc-elhb8j-12 cvsUXu">
#         </div>
#         <div class="sc-elhb8j-12 cvsUXu">
#         </div>
#         <section class="sc-elhb8j-11 eHuOnX">
#          <a aria-label="app store link" class="sc-16nfz79-0 blTnzu" href="https://link.zomato.com/xqzv/downloadZomatoIos" target="_blank">
#           <div class="sc-s1isp7-1 fxuOHl" height="4rem" width="13.7rem">
#            <div alt="image" class="sc-s1isp7-3 dqJnoA" src="">
#            </div>
#            <img alt="image" class="sc-s1isp7-5 cqxheR" loading="lazy" src=""/>
#           </div>
#          </a>
#          <div class="sc-elhb8j-12 cvsUXu">
#          </div>
#          <a aria-label="app store link" class="sc-16nfz79-0 blTnzu" href="https://link.zomato.com/xqzv/downloadZomatoAndroid" target="_blank">
#           <div class="sc-s1isp7-1 fxuOHl" height="4rem" width="13.7rem">
#            <div alt="image" class="sc-s1isp7-3 dqJnoA" src="">
#            </div>
#            <img alt="image" class="sc-s1isp7-5 cqxheR" loading="lazy" src=""/>
#           </div>
#          </a>
#         </section>
#        </div>
#       </div>
#       <hr class="sc-elhb8j-13 bskCAo"/>
#       <p class="sc-elhb8j-5 kBllqA">
#        By continuing past this page, you agree to our Terms of Service, Cookie Policy, Privacy Policy and Content Policies. All trademarks are properties of their respective owners. 2008-2024 © Zomato™ Ltd. All rights reserved.
#       </p>
#      </div>
#     </footer>
#     <div class="sc-iERxws fFZiud">
#     </div>
#    </div>
#   </div>
#   <script>
#    window.__PRELOADED_STATE__ = JSON.parse("{\"pages\":{\"current\":{\"name\":\"restaurant\",\"pageTitle\":\"Reviews of Ettarra, Juhu, Mumbai | Zomato \",\"pageDescription\":\"Reviews of Ettarra Juhu; see all unbiased reviews of Ettarra Mumbai for delivery and dining on Zomato.\",\"resId\":20468935,\"pageUrl\":\"/mumbai/ettarra-1-juhu/reviews\",\"title\":\"Reviews\",\"subType\":\"reviews\",\"key\":\"reviews\",\"ogTitle\":\"Reviews of Ettarra, Juhu, Mumbai | Zomato \",\"ogDescription\":\"Reviews of Ettarra Juhu; see all unbiased reviews of Ettarra Mumbai for delivery and dining on Zomato.\",\"ogUrl\":\"/mumbai/ettarra-1-juhu/reviews\",\"ampHtmlUrl\":\"/mumbai/ettarra-1-juhu/reviews?amp=1\",\"isFloodReliefRes\":false,\"isNoIndex\":false,\"show_rating_v15\":true,\"showBookingV2\":false,\"isMobile\":0,\"isOAuthV2Enabled\":false,\"useAuthSdkForLogin\":true,\"useAuthSdkForLogout\":false,\"gaPageType\":\"Restaurant\"},\"contact\":{\"contactPageBannerData\":[],\"snippetData\":[],\"formData\":{},\"buisinessEnquiriesData\":{}},\"gift\":{\"crystalData\":{}},\"goodbye\":{},\"restaurant\":{\"20468935\":{\"sections\":{\"SECTION_REVIEWS\":{\"status\":\"success\",\"message\":\"\",\"entities\":[{\"entity_type\":\"REVIEWS\",\"entity_ids\":[198140148,196676807,196048573,195844039,194559500]}],\"pageReviewsText\":\"Showing 1-5 of 281 reviews\",\"numberOfPages\":51,\"noReviewsText\":\"\",\"currentPage\":1,\"currentFilter\":\"reviews-dd\",\"currentSort\":\"dd\"},\"SECTION_IMAGE_CAROUSEL\":{\"entities\":[{\"entity_type\":\"IMAGES\",\"entity_ids\":[\"r_U2NjA4NTQyODU5\",\"r_4ODI5MzIyODE3M\",\"r_QwOTgwMjk2NTk2\",\"r_TAxMzgwNzI3OTQ\",\"r_NzU3Mjc5MzYMDI\",\"r_3NTg5NTMzMzMyN\",\"r_OTQ2MzEyNTIwMz\",\"r_Tk5NzEzNjYxMzk\",\"r_DQxNDUxMTI2NTg\"]}],\"has_more_photo\":true,\"obpImage\":{\"entity_type\":\"IMAGES\",\"entity_ids\":\"r_NjQxMzgzOTcyOT\"},\"is_partner\":false},\"SECTION_BASIC_INFO\":{\"res_id\":20468935,\"name\":\"Ettarra\",\"cuisine_string\":\"Cafe, Desserts, Coffee, Bakery, Beverages, Shake\",\"rating\":{\"has_fake_reviews\":0,\"aggregate_rating\":\"4.8\",\"rating_text\":\"4.6\",\"rating_subtitle\":\"Excellent\",\"rating_color\":\"3F7E00\",\"votes\":\"201\",\"subtext\":\"REVIEWS\",\"is_new\":false},\"rating_new\":{\"newlyOpenedObj\":null,\"suspiciousReviewObj\":null,\"ratings\":{\"DINING\":{\"rating_type\":\"DINING\",\"rating\":\"4.8\",\"reviewCount\":\"201\",\"reviewTextSmall\":\"201 Reviews\",\"subtext\":\"201 Dining Reviews\",\"color\":\"#1C1C1C\",\"ratingV2\":\"4.8\",\"subtitle\":\"DINING\",\"sideSubTitle\":\"Dining Ratings\",\"bgColorV2\":{\"type\":\"green\",\"tint\":\"800\"},\"newOnDining\":false},\"DELIVERY\":{\"rating_type\":\"DELIVERY\",\"rating\":\"4.4\",\"reviewCount\":\"264\",\"reviewTextSmall\":\"264 Reviews\",\"subtext\":\"264 Delivery Reviews\",\"color\":\"#E23744\",\"ratingV2\":\"4.4\",\"subtitle\":\"DELIVERY\",\"sideSubTitle\":\"Delivery Ratings\",\"bgColorV2\":{\"type\":\"green\",\"tint\":\"700\"},\"newOnDelivery\":false}}},\"res_status_text\":\"Closed for dining\",\"timing\":{\"timing_desc\":\"Opens tomorrow at 12midnight\",\"customised_timings\":{\"opening_hours\":[{\"timing\":\"24 Hours\",\"days\":\"Mon, Wed-Sun\"},{\"timing\":\"Closed\",\"days\":\"Tue\"}]},\"show_open_now\":true,\"show_timing_info\":true},\"is_delivery_only\":false,\"is_perm_closed\":false,\"is_temp_closed\":false,\"is_opening_soon\":0,\"should_ban_ugc\":false,\"is_shelled\":false,\"media_alert\":0,\"learn_more_text\":\"Learn More\",\"res_thumb\":\"https://b.zmtcdn.com/data/pictures/5/20468935/886ba0eaa97c802c602f7b3d86174187_featured_v2.jpg\",\"disclaimer_text\":\"\",\"resUrl\":\"/mumbai/ettarra-1-juhu\",\"is_partner\":false},\"SECTION_FEATURE_RAIL\":[],\"SECTION_RES_HEADER_DETAILS\":{\"LOCALITY\":{\"text\":\"Juhu Residency Boutique Hotel, Juhu, Mumbai\",\"url\":\"https://www.zomato.com/mumbai/juhu-restaurants\"},\"CUISINES\":[{\"deeplink\":\"zomato://search?deeplink_filters=WyJ7XCJjb250ZXh0XCI6XCJhbGxcIn0iLCJ7XCJjdWlzaW5lX2lkXCI6W1wiMzBcIl19Il0%3D\",\"url\":\" ...
#   </script>
#   <script defer="" src="https://www.zomato.com/zpaykit/js/v4/hook.js">
#   </script>
#   <script>
#    window.zomato = {};
#         window.zomato.fbAppId = 288523881080;
#         window.zomato.googleAppId = "442739719837.apps.googleusercontent.com";
#         window.zomato.googleMapAPIKey = "AIzaSyAWI5mHPh-9Bkxa7AMkINGaWQTZuL1Ss1o";
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">
#    [2322,7472,7635,7284,9089,7602,5367,4057,5865,9247,359,5357,3773,1510,2783,483,6013,1638,276,7896,4524,1637,9791,1559,9540,216,8375,9885,2581,9642,7525,2472,2928,4554,2520,7721,4494,1301,7578,999,3703,5519,6464]
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">
#    {"namedChunks":["StructuredData","pages-common-Navbar","components-RestaurantNavbar","layoutEntries-resNavDesktopIndex","layoutEntries-uniSearchDesContainer","pages-Restaurant","layoutEntries-resDesktopIndex","partials-RestaurantHeaderV2","ResHeaderActionBar","layoutEntries-ResHeaderDesktop","subpages-Reviews","PhotoViewerWrapper","components-FullPageAdRestaurant","Footers","ZomatoFooter","zwebmolecules-dist-Login","PageBlocker"]}
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/runtime-dd9689f0de0be432cda9.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/lodash-es-5aa3c1be995b214b4787.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/babel-62f92632ee0e45a78e30.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/zomato-ca3bc3a001f31cbf113c.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/recompose-c61168b126fe51751d95.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/react-redux-ac36eac8afa75489c0aa.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/redux-saga-e2a91de414ce4c74db92.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/react-dom-415db000d9c45cbaa5e2.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/styled-components-c5c655a4b6f04a94ebe9.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/redux-626552d9bf258284ba5d.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/7003-5be4551477fbeea8002a.js">
#   </script>
#   <script async="" data-chunk="main" src="https://zwstatic.zomato.com/main-e748d14085c2fba7edd5.js">
#   </script>
#   <script async="" data-chunk="StructuredData" src="https://zwstatic.zomato.com/StructuredData-4179ad88df8fce730511.js">
#   </script>
#   <script async="" data-chunk="pages-common-Navbar" src="https://zwstatic.zomato.com/pages-common-Navbar-c37dd516a209c0e680e7.js">
#   </script>
#   <script async="" data-chunk="components-RestaurantNavbar" src="https://zwstatic.zomato.com/components-RestaurantNavbar-c71236302e4c3ea790d0.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resNavDesktopIndex" src="https://zwstatic.zomato.com/rxjs-6bb60bde81ee609da043.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resNavDesktopIndex" src="https://zwstatic.zomato.com/9089-4fec7fcff683257323de.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resNavDesktopIndex" src="https://zwstatic.zomato.com/7602-6763f5d4098f0e6aa82c.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resNavDesktopIndex" src="https://zwstatic.zomato.com/5367-c2dd91b5fd3253186cda.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resNavDesktopIndex" src="https://zwstatic.zomato.com/4057-5ae2182a729bca6a91ce.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resNavDesktopIndex" src="https://zwstatic.zomato.com/layoutEntries-resNavDesktopIndex-e63fecd9bc026153ad27.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-uniSearchDesContainer" src="https://zwstatic.zomato.com/9247-d7116c1c2f59c653f004.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-uniSearchDesContainer" src="https://zwstatic.zomato.com/layoutEntries-uniSearchDesContainer-fcdc685d79b81a41fc88.js">
#   </script>
#   <script async="" data-chunk="pages-Restaurant" src="https://zwstatic.zomato.com/3773-79c4d519c7c6f4e28306.js">
#   </script>
#   <script async="" data-chunk="pages-Restaurant" src="https://zwstatic.zomato.com/1510-1223017b29026f0bf897.js">
#   </script>
#   <script async="" data-chunk="pages-Restaurant" src="https://zwstatic.zomato.com/pages-Restaurant-e0c76b863f393ef76001.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resDesktopIndex" src="https://zwstatic.zomato.com/483-947e5f92489388a13609.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resDesktopIndex" src="https://zwstatic.zomato.com/6013-02c7d6ee851e5bdfa58d.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-resDesktopIndex" src="https://zwstatic.zomato.com/layoutEntries-resDesktopIndex-c2791b5a31d26db8d747.js">
#   </script>
#   <script async="" data-chunk="partials-RestaurantHeaderV2" src="https://zwstatic.zomato.com/276-e1b95c16d1f0d797ea51.js">
#   </script>
#   <script async="" data-chunk="partials-RestaurantHeaderV2" src="https://zwstatic.zomato.com/7896-91c6fc7aa8bb5c1592d3.js">
#   </script>
#   <script async="" data-chunk="partials-RestaurantHeaderV2" src="https://zwstatic.zomato.com/partials-RestaurantHeaderV2-1455eabbf7a4400d15a3.js">
#   </script>
#   <script async="" data-chunk="ResHeaderActionBar" src="https://zwstatic.zomato.com/ResHeaderActionBar-7c58ca966965c79cd29f.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-ResHeaderDesktop" src="https://zwstatic.zomato.com/9791-56ef1c6a756bee55da7a.js">
#   </script>
#   <script async="" data-chunk="layoutEntries-ResHeaderDesktop" src="https://zwstatic.zomato.com/layoutEntries-ResHeaderDesktop-45b0b45287547c5d0819.js">
#   </script>
#   <script async="" data-chunk="subpages-Reviews" src="https://zwstatic.zomato.com/9540-0e5bb9fbdf6b080ca549.js">
#   </script>
#   <script async="" data-chunk="subpages-Reviews" src="https://zwstatic.zomato.com/216-91dbb161ae6ba163ae05.js">
#   </script>
#   <script async="" data-chunk="subpages-Reviews" src="https://zwstatic.zomato.com/8375-f9f57ccd2799d8265840.js">
#   </script>
#   <script async="" data-chunk="subpages-Reviews" src="https://zwstatic.zomato.com/9885-6fc2170ed6c584f61868.js">
#   </script>
#   <script async="" data-chunk="subpages-Reviews" src="https://zwstatic.zomato.com/2581-fa934e7b667ce84d6079.js">
#   </script>
#   <script async="" data-chunk="subpages-Reviews" src="https://zwstatic.zomato.com/9642-8ecd1d95f408d3b9b956.js">
#   </script>
#   <script async="" data-chunk="subpages-Reviews" src="https://zwstatic.zomato.com/subpages-Reviews-1c9a4f449c2ea7c6fac4.js">
#   </script>
#   <script async="" data-chunk="PhotoViewerWrapper" src="https://zwstatic.zomato.com/PhotoViewerWrapper-2e0a62f28c6f55fe7cc3.js">
#   </script>
#   <script async="" data-chunk="components-FullPageAdRestaurant" src="https://zwstatic.zomato.com/2928-cb7eae68bce3d24300dc.js">
#   </script>
#   <script async="" data-chunk="components-FullPageAdRestaurant" src="https://zwstatic.zomato.com/4554-4adf66c3a5db19ec3d5f.js">
#   </script>
#   <script async="" data-chunk="components-FullPageAdRestaurant" src="https://zwstatic.zomato.com/components-FullPageAdRestaurant-23b6539d078f6a0207b4.js">
#   </script>
#   <script async="" data-chunk="Footers" src="https://zwstatic.zomato.com/Footers-ff9e5846e90ac976feb4.js">
#   </script>
#   <script async="" data-chunk="ZomatoFooter" src="https://zwstatic.zomato.com/4494-1e677d010045aa2cbc38.js">
#   </script>
#   <script async="" data-chunk="ZomatoFooter" src="https://zwstatic.zomato.com/1301-aeda8b6274a596925c56.js">
#   </script>
#   <script async="" data-chunk="ZomatoFooter" src="https://zwstatic.zomato.com/ZomatoFooter-c2005188dbe0d1b7dda7.js">
#   </script>
#   <script async="" data-chunk="zwebmolecules-dist-Login" src="https://zwstatic.zomato.com/999-9ded7225a69dde7e9ce5.js">
#   </script>
#   <script async="" data-chunk="zwebmolecules-dist-Login" src="https://zwstatic.zomato.com/3703-4e0dca1da0910da4db0b.js">
#   </script>
#   <script async="" data-chunk="zwebmolecules-dist-Login" src="https://zwstatic.zomato.com/zwebmolecules-dist-Login-4abc59e559323b8b3e08.js">
#   </script>
#   <script async="" data-chunk="PageBlocker" src="https://zwstatic.zomato.com/PageBlocker-d9d6ead498029ef71e3a.js">
#   </script>
#   <script defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <script>
#    window.dataLayer = [{}];
#       var stdeviceProperties = {
#         'user_agent': navigator.userAgent,
#         'user_device_acronym': 'd'
#       };
#       window.dataLayer.push(stdeviceProperties);
#       function gtag() {
#         dataLayer.push(arguments);
#       }
#       gtag('js', new Date());
#       gtag('config', 'AW-958674130');
#       gtag('config', 'G-2XVFHLPTVP');
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-MKPZQ6');
#   </script>
#   <script defer="" src="https://www.googletagmanager.com/gtag/js?id=AW-958674130">
#   </script>
#  </body>
# </html>

# %%
results = soup.findAll('p')

# %%
results
# Out:
# [<p class="sc-1hez2tp-0 sc-fCPvlr dbaWnN" color="#EF4F5F">Detect current location</p>,
#  <p class="sc-1hez2tp-0 sc-hAXbOi jJsAxK">Using GPS</p>,
#  <p class="sc-1hez2tp-0 sc-bYTsla hUkOLL">View Gallery</p>,
#  <p class="sc-1hez2tp-0 OgtQR">All Reviews</p>,
#  <p class="sc-1hez2tp-0 OgtQR">Newest First</p>,
#  <p class="sc-1hez2tp-0 sc-fPCuyW hWkbSv">Khushboo Ratnani</p>,
#  <p class="sc-1hez2tp-0 fKvqMN time-stamp" color="#9C9C9C">4 days ago</p>,
#  <p class="sc-1hez2tp-0 sc-rzOft eaqKit">Many stories with the place,,,,, it has this unexplained vibe which attracts me everytime and to be specific, I have got all my special friends to visit her</p>,
#  <p class="sc-1hez2tp-0 fKvqMN" color="#9C9C9C">0<!-- --> <!-- -->Votes for helpful<!-- -->, <!-- -->1<!-- --> <!-- -->Comment</p>,
#  <p class="sc-1hez2tp-0 sc-fPCuyW hWkbSv">Renu Joshi</p>,
#  <p class="sc-1hez2tp-0 fKvqMN time-stamp" color="#9C9C9C">9 days ago</p>,
#  <p class="sc-1hez2tp-0 sc-rzOft eaqKit">You forgot to send sugar with coffee/the rest of your coffee is good</p>,
#  <p class="sc-1hez2tp-0 fKvqMN" color="#9C9C9C">0<!-- --> <!-- -->Votes for helpful<!-- -->, <!-- -->1<!-- --> <!-- -->Comment</p>,
#  <p class="sc-1hez2tp-0 sc-fPCuyW hWkbSv">Vedant</p>,
#  <p class="sc-1hez2tp-0 fKvqMN time-stamp" color="#9C9C9C">11 days ago</p>,
#  <p class="sc-1hez2tp-0 sc-rzOft eaqKit">The filter coffee was brilliant and so were snacks. We had the drizzled paparoti and Nutella Berliner which were lip smacking good. They serve complimentary banana chips which were one of the best I have had in a while. Asif Sheikh- our server was very courteous.</p>,
#  <p class="sc-1hez2tp-0 fKvqMN" color="#9C9C9C">0<!-- --> <!-- -->Votes for helpful<!-- -->, <!-- -->1<!-- --> <!-- -->Comment</p>,
#  <p class="sc-1hez2tp-0 sc-fPCuyW hWkbSv">Archis</p>,
#  <p class="sc-1hez2tp-0 fKvqMN time-stamp" color="#9C9C9C">12 days ago</p>,
#  <p class="sc-1hez2tp-0 sc-rzOft eaqKit">One of the best places to go to, for a vibe, indie music, and some of the most amazing coffees. If you do come here do try the tarts.</p>,
#  <p class="sc-1hez2tp-0 fKvqMN" color="#9C9C9C">0<!-- --> <!-- -->Votes for helpful<!-- -->, <!-- -->1<!-- --> <!-- -->Comment</p>,
#  <p class="sc-1hez2tp-0 sc-fPCuyW hWkbSv">Akash Negandhi</p>,
#  <p class="sc-1hez2tp-0 fKvqMN time-stamp" color="#9C9C9C">17 days ago</p>,
#  <p class="sc-1hez2tp-0 sc-rzOft eaqKit">Enjoyed the whole experience! Special mention to Asif for catering us</p>,
#  <p class="sc-1hez2tp-0 fKvqMN" color="#9C9C9C">0<!-- --> <!-- -->Votes for helpful<!-- -->, <!-- -->1<!-- --> <!-- -->Comment</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Who We Are</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Blog</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Work With Us</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Investor Relations</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Report Fraud</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Press Kit</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Contact Us</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Zomato</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Blinkit</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Feeding India</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Hyperpure</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Zomaland</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Partner With Us</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Apps For You</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Privacy</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Security</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Terms</p>,
#  <p class="sc-elhb8j-16 dxcfRo">Sitemap</p>,
#  <p class="sc-elhb8j-5 kBllqA">By continuing past this page, you agree to our Terms of Service, Cookie Policy, Privacy Policy and Content Policies. All trademarks are properties of their respective owners. 2008-2024 © Zomato™ Ltd. All rights reserved.</p>]

# %%
for result in results:
    if 'eaqKit' in str(result):
        print(result.text)
# Out:
# Many stories with the place,,,,, it has this unexplained vibe which attracts me everytime and to be specific, I have got all my special friends to visit her
# You forgot to send sugar with coffee/the rest of your coffee is good
# The filter coffee was brilliant and so were snacks. We had the drizzled paparoti and Nutella Berliner which were lip smacking good. They serve complimentary banana chips which were one of the best I have had in a while. Asif Sheikh- our server was very courteous.
# One of the best places to go to, for a vibe, indie music, and some of the most amazing coffees. If you do come here do try the tarts.
# Enjoyed the whole experience! Special mention to Asif for catering us
